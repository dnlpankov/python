# %%
import os
os.environ['OAUTHLIB_INSECURE_TRANSPORT'] = '1'

from datetime import datetime
import pytz

import os
import json
import requests
from requests_oauthlib import OAuth2Session
from datetime import datetime
from urllib.parse import urlencode
import pandas as pd
import re
import time

# %%
creds_path="./"
test=0
if test==1:
    limit_per_request=1
    sleep_time_for_one_campaign=0
else:
    limit_per_request=30
    sleep_time_for_one_campaign=0.6

# %%
# Path to Aweber credentials file
aweber_creds = creds_path+ 'aweber_credentials.json'

# Load the credentials
with open(aweber_creds, 'r') as file:
    credentials = json.load(file)


# Assign creds to variables
client_id = credentials['client_id']
client_secret = credentials['client_secret']
redirect_uri = 'http://localhost:5000/oauth/callback'

# OAuth2 endpoints
authorization_base_url = 'https://auth.aweber.com/oauth2/authorize'
token_url = 'https://auth.aweber.com/oauth2/token'

# Scopes
scopes = ['email.read', 'account.read', 'list.read', 'subscriber.read']

# File to store tokens
token_file = 'aweber_tokens.json'

def save_tokens(tokens):
    with open(token_file, 'w') as f:
        json.dump(tokens, f)

def load_tokens():
    if os.path.exists(token_file):
        with open(token_file, 'r') as f:
            return json.load(f)
    return None

def refresh_tokens(refresh_token):
    extra = {'client_id': client_id, 'client_secret': client_secret}
    aweber = OAuth2Session(client_id, token={'refresh_token': refresh_token}, auto_refresh_kwargs=extra, auto_refresh_url=token_url, token_updater=save_tokens)
    tokens = aweber.refresh_token(token_url, refresh_token=refresh_token)
    save_tokens(tokens)
    return tokens

def get_aweber_session():
    tokens = load_tokens()
    
    if tokens is None:
        raise Exception("No tokens found. Please run the initial setup script first.")
    
    # Check if token has expired
    expiration_time = datetime.fromtimestamp(tokens['expires_at'])
    if datetime.now() >= expiration_time:
        tokens = refresh_tokens(tokens['refresh_token'])
    
    return OAuth2Session(client_id, token=tokens, scope=scopes), tokens['access_token']

def get_campaigns(list_id, account_id, campaign_type, start=0, limit=1000):
    aweber, access_token = get_aweber_session()
    try:
        params = {'ws.op': 'find', 'campaign_type': campaign_type, 'ws.start': start, 'ws.size': limit}
        campaigns_url = f'https://api.aweber.com/1.0/accounts/{account_id}/lists/{list_id}/campaigns?{urlencode(params)}'
        headers = {
            'Accept': 'application/json',
            'User-Agent': 'AWeber-Python-code-sample/1.0',
            'Authorization': f'Bearer {access_token}'
        }
        print(f"Fetching campaigns with URL: {campaigns_url}")
        response = aweber.get(campaigns_url, headers=headers)
        response.raise_for_status()
        campaigns = response.json()
        print("Campaigns fetched successfully!")
        return campaigns
    except requests.exceptions.RequestException as e:
        print(f"Error fetching campaigns for list {list_id}:", e)
        return {'entries': []}
# Function to convert iso format time to CET
def convert_to_cet(time_str):
    #print(time_str)
    time_str_cet=None
    if time_str is not None:
        input_time = datetime.fromisoformat(time_str)
        cet_tz = pytz.timezone("Europe/Berlin")
        cet_time = input_time.astimezone(cet_tz)
        time_str_cet=cet_time.strftime('%Y-%m-%d %H:%M:%S')
    return time_str_cet

def get_all_lists_for_account(account_id):
    # response = requests.get(f'https://api.aweber.com/1.0/accounts/{account_id}/lists', headers=headers)
    # lists = response.json()
    try:
        aweber, access_token = get_aweber_session()
        #print(access_token)
        lists_url = f'https://api.aweber.com/1.0/accounts/{account_id}/lists'
        headers = {
            'Accept': 'application/json',
            'User-Agent': 'AWeber-Python-code-sample/1.0',
            'Authorization': f'Bearer {access_token}'
        }
        response = requests.get(lists_url, headers=headers)
        response.raise_for_status()
        campaign_details = response.json()


        print(f"Details for campaign {account_id} fetched successfully!")
        lists=[]
        for entry in campaign_details['entries']:
            lists+=[entry['id']]

        return lists
    except requests.exceptions.RequestException as e:
        print(f"Error fetching lists for account {account_id}:", e)
        return {}

def get_campaign_details(account_id, list_id, campaign_id, campaign_type, access_token):
    try:
        
        campaign_details_url = f'https://api.aweber.com/1.0/accounts/{account_id}/lists/{list_id}/campaigns/{campaign_type}{campaign_id}'
        headers = {
            'Accept': 'application/json',
            'User-Agent': 'AWeber-Python-code-sample/1.0',
            'Authorization': f'Bearer {access_token}'
        }
        response = requests.get(campaign_details_url, headers=headers)
        response.raise_for_status()
        campaign_details = response.json()
        campaign_details['sent_at_cet'] = convert_to_cet(campaign_details['sent_at'])
        campaign_details['list_id'] = list_id
        print(f"Details for campaign {campaign_id} fetched successfully!")
        time.sleep(sleep_time_for_one_campaign)
        return campaign_details
    except requests.exceptions.RequestException as e:
        print(f"Error fetching details for campaign {campaign_id}:", e)
        return {}



def fetch_all_campaigns_of_list_and_type(account_id, list_id, campaign_type, data_nature):
    aweber, access_token = get_aweber_session()
    

    campaigns_response = get_campaigns(list_id, account_id, campaign_type, limit=limit_per_request)
    campaigns = campaigns_response['entries']
    all_campaigns_of_list_and_type_details = []
    for campaign in campaigns:
        campaign_id = campaign['id']
        print(f"campaign is {campaign_id} and list is {list_id}")
        if data_nature=='campaigns_stats':
            campaign_details = get_campaign_details(account_id, list_id, campaign_id, campaign_type, access_token)
        elif data_nature=='campaigns_characteristics':
            campaign_details = get_campaign_characteristics(account_id, list_id, campaign_id, campaign_type, access_token)
        #print(type(campaign_details['sent_at_cet']))
        all_campaigns_of_list_and_type_details.append(campaign_details)
    return all_campaigns_of_list_and_type_details

def fetch_all_campaigns(account_id, campaign_type_set, data_nature):
    all_campaigns_details = []
    lists=get_all_lists_for_account(account_id)
    #print(entries)
    for list_id in lists:
        for campaign_type in campaign_type_set:
            all_campaigns_details = all_campaigns_details+fetch_all_campaigns_of_list_and_type(account_id, list_id, campaign_type, data_nature)
    return all_campaigns_details, lists

# %%
# Example usage:
account_id = 2007954  # Replace with actual account ID
list_id = 6405738  # Replace with actual list ID
campaign_type = 'b'  # Replace with actual campaign type (e.g., 'broadcast', 'followup', etc.)

all_campaigns_details_final, lists = fetch_all_campaigns(account_id, campaign_type_set=['b', 'f'], data_nature='campaigns_stats')

# Print or process all campaign details
#print(json.dumps(all_campaigns_details_final, indent=2))

# %% [markdown]
# ## Uploading Data to postgres

# %%
# with open(sql_creds, 'r') as file:
#     sql_credentials = json.load(file)

# sql_credentials['string']

# %%
from sqlalchemy import create_engine
#import pandas as pd

sql_creds = creds_path+'postgres_credentials.json'

# Load the credentials
with open(sql_creds, 'r') as file:
    sql_credentials = json.load(file)

def load_data_to_db(json_vector=all_campaigns_details_final, schema='danila', table='stg_aweber__campaign_data'):
    engine = create_engine(sql_credentials['string'])
    df=pd.json_normalize(json_vector)
    # Define CET timezone
    cet = pytz.timezone('Europe/Paris')
        
    # Add current timestamp in CET timezone
    df['updated_at_cet'] = datetime.now(cet)

    # Load data into the specified schema in the database
    df.to_sql(table, engine, if_exists='replace', index=False, schema='danila')

if __name__ == "__main__":
    load_data_to_db()

# %% [markdown]
# # Getting campaign country and brand

# %%
# Function to extract the specific part from the body_text
def extract_cosmic_slot(body_text):
    print(body_text)
    pattern = r'-email-([^-]*)-([^-]*)-([^-]*)-'
    match = re.search(pattern, body_text)
    #string = '-email-nl-xxxxxxxxxxxxxxxx-justbit-'
    if match:
        return match.group(1), match.group(3)
    return None, None

def get_campaign_characteristics(account_id, list_id, campaign_id, campaign_type, access_token):
    try:
        aweber, access_token = get_aweber_session()
        campaign_details_url = f'https://api.aweber.com/1.0/accounts/{account_id}/lists/{list_id}/broadcasts/{campaign_id}'
        
        headers = {
            'Accept': 'application/json',
            'User-Agent': 'AWeber-Python-code-sample/1.0',
            'Authorization': f'Bearer {access_token}'
        }
        response = requests.get(campaign_details_url, headers=headers)
        response.raise_for_status()
        json_data = response.json()
        country_code, brand_name=extract_cosmic_slot(json_data['body_text'])
        extracted_data = {
            'brand_name': brand_name,
            'country_code': country_code,
            'sent_at': json_data['sent_at'],
            'sent_at_cet': convert_to_cet(json_data['sent_at']), # Convert to CET timezone
            'broadcast_id': json_data['broadcast_id'],
            'campaign_type': campaign_type,
            'campaign_id': campaign_id,
            'account_id': account_id,
            'list_id': list_id,
            'subject': json_data['subject'],
            'num_complaints': json_data['stats']['num_complaints'],
            'num_emailed': json_data['stats']['num_emailed'],
            'num_undeliv': json_data['stats']['num_undeliv'],
            'unique_clicks': json_data['stats']['unique_clicks'],
            'unique_opens': json_data['stats']['unique_opens']
        }
        # campaign_details['sent_at_cet'] = convert_to_cet(campaign_details['sent_at'])
        # campaign_details['list_id'] = list_id
        print(f"Details for campaign {campaign_id} fetched successfully!")
        time.sleep(sleep_time_for_one_campaign)
        return extracted_data
    except requests.exceptions.RequestException as e:
        print(f"Error fetching details for campaign {campaign_id}:", e)
        return {}

campaign_id= 57913875 # 57961057
account_id = 2007954  # Replace with actual account ID
list_id = 6405738  # Replace with actual list ID
#aweber, access_token = get_aweber_session()
campaign_characteristics, lists = fetch_all_campaigns(account_id, campaign_type_set='b', data_nature='campaigns_characteristics')




#print(campaign_characteristics)
# Out:
# Details for campaign 2007954 fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6405738/campaigns?ws.op=find&campaign_type=b&ws.start=0&ws.size=30
# Campaigns fetched successfully!
# campaign is 57961057 and list is 6405738
# Unleash Fiery Fortunes with Coin Volcano
#
#                         Coin Volcano highest RTP
#
# https://m.media13aff.com/Redirect.aspx?mid=100&sid=4316&affid=506&cid=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-spinbro-undefined-trickyspins_email_newbase
#
#             Get ready for an explosive adventure with Coin Volcano, the latest 3x3 reel game by Booongo!
#
# Featuring the thrilling hold & win bonus game and the enhanced ultra bonus game, this high RTP slot
#
# https://m.media13aff.com/Redirect.aspx?mid=100&sid=4316&affid=506&cid=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-spinbro-undefined-trickyspins_email_newbase
#  promises endless excitement.
#
# Watch as reels erupt with coins, volcano multipliers, and four fiery jackpots. trigger the bonus game with three symbols on the middle reel, and enjoy respins that reset with every new symbol. Look out for the scorching ball, which collects all coin and jackpot values in view.
#
#
#             You received this message because you have subscribed to TrickySpins.
# Learn more about the new offers, playing strategies and best practices!
#
# https://trickyspins.com/au/home
#
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 57961057 fetched successfully!
# campaign is 57913904 and list is 6405738
# Enjoy up to 20% Cashback
#
#                         daily cashback 20%
#
# https://bingotraff.com/gd786bb1d?subid=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-bingobonga-undefined-trickyspins_email_newbase
#
#             Get ready to spin and win like never before at BingoBonga Casino!
#
# We're introducing our DAILY CASHBACK offer
#
# https://bingotraff.com/gd786bb1d?subid=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-bingobonga-undefined-trickyspins_email_newbase
#
# Get up to 20% back EVERY. SINGLE. DAY!
#
# https://bingotraff.com/gd786bb1d?subid=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-bingobonga-undefined-trickyspins_email_newbase
#
#
# Imagine, play your favorite games  and if luck doesn't quite swing your way, we've got your back with up to 20% cashback!
#
#
#             You received this message because you have subscribed to TrickySpins.
# Learn more about the new offers, playing strategies and best practices!
#
#
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 57913904 fetched successfully!
# campaign is 57913875 and list is 6405738
# Refferal Programm
#
#                         Refferal program 200 free spins for a friend
#
# https://m.media13aff.com/Redirect.aspx?mid=68&sid=4303&affid=506&cid=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-cosmicslot-undefined-trickyspins_email_newbase
#
#             Get ready to embark on an interstellar adventure with Cosmic Slot
# Invite your friends to join the Cosmic Slot universe, and we'll thank you with an astronomical gift: 200 Free Spins
#
# https://m.media13aff.com/Redirect.aspx?mid=68&sid=4303&affid=506&cid=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-cosmicslot-undefined-trickyspins_email_newbase
#  for each friend who signs up and makes their first deposit.
#
#
#             You received this message because you have subscribed to TrickySpins.
# Learn more about the new offers, playing strategies and best practices!
#
# https://trickyspins.com
#
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 57913875 fetched successfully!
# campaign is 57913863 and list is 6405738
# 100 mBTC are waiting for you!
#
#                         Crypto Welcome Offer up to 100 mBTC +100 free spins + 1 bonus crab
#
# https://media.rabona.com/redirect.aspx?pid=2044557&lpid=14765&bid=6968&var2=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-rabona-undefined-trickyspins_email_newbase
#
#             Get ready to boost your balance with up to 100 mBTC
#
# https://media.rabona.com/redirect.aspx?pid=2044557&lpid=14765&bid=6968&var2=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-rabona-undefined-trickyspins_email_newbase
#
# on your first deposit!
#
# https://media.rabona.com/redirect.aspx?pid=2044557&lpid=14765&bid=6968&var2=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-rabona-undefined-trickyspins_email_newbase
#
#
# This generous bonus is designed to extend your playtime and enhance your chances of hitting those big wins.
#
#             You received this message because you have subscribed to TrickySpins.
#
# https://trickyspins.com/
#
# Learn more about the new offers, playing strategies and best practices!
#
# https://trickyspins.com/
#
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 57913863 fetched successfully!
# campaign is 57913506 and list is 6405738
# Discover offers of the week!
#
# Discover the Top 3 Welcome Bonuses of the Week!
#
#             Are you ready to embark on a thrilling adventure with the best bonuses of the week? At TrickySpins, we’ve handpicked the top 3 welcome bonuses just for you, ensuring your gaming experience starts with a bang!
#
#
#                         100% up to $750+ 200 free spins+ 1 bonus crab
#
# https://playluckywins.com/j59f1f278&clickID=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-luckywins-undefined-trickyspins_email_newbase
#
#                         225% bonus up to $2910
#
# https://record.joinaff.com/_GUtnFvlzSb3fjgRf_EGLtmNd7ZgqdRLk/11/?pg=2&payload=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-winlegends-undefined-trickyspins_email_newbase
#
#                         100% up to $1500 + 100 free spins
#
# https://media.luckydaysaffiliates.com/redirect.aspx?pid=7424&bid=1523&clickid=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-luckydays-undefined-trickyspins_email_newbase
#
#             You received this message because you have subscribed to TrickySpins.
# Learn more about the new offers, playing strategies and best practices!
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 57913506 fetched successfully!
# campaign is 57913750 and list is 6405738
# Spades Queen is here...
#
#                         First Deposit Bonus 100% up to 750 C$ + 100 FS
#
# https://spadesqueenplay.com/dc802dc43?clickid=email-202401010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-spadesqueen-undefined-trickyspins_email_newbase
#
#             Get ready to reload, explore, and conquer!
#
# Turbo-charge your luck with a 100%
# first deposit bonus up to 750 С$ and 100 free spins
#
# https://spadesqueenplay.com/dc802dc43?clickid=email-202401010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-spadesqueen-undefined-trickyspins_email_newbase
# .
# Are you ready to unlock the mystical secrets and big rewards? Use code WELCOME100 then welcome to the winning team.
#
#             You received this message because you have subscribed to TrickySpins.
# Learn more about the new offers, playing strategies and best practices!
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 57913750 fetched successfully!
# campaign is 57878731 and list is 6405738
# Discover offers of the week!
#
# Discover the Top 3 Welcome Bonuses of the Week!
#
#             Are you ready to embark on a thrilling adventure with the best bonuses of the week? At TrickySpins, we’ve handpicked the top 3 welcome bonuses just for you, ensuring your gaming experience starts with a bang!
#
#
#                         100% up to $750+ 200 free spins+ 1 bonus crab
#
# https://lunubetplay.com/j0bb92ed9?subid=email-202301010000-undefined-undefined-0-email-ca-{{subscriber.uuid}}-lunubet-undefined-trickyspins_email_newbase
#
#                         225% bonus up to $2910
#
# https://record.joinaff.com/_GUtnFvlzSb3fjgRf_EGLtmNd7ZgqdRLk/11/?pg=2&payload=email-202401010000-undefined-undefined-0-email-ca-{{subscriber.uuid}}-winlegends-undefined-trickyspins_email_newbase
#
#                         100% up to $1500 + 100 free spins
#
# https://media.luckydaysaffiliates.com/redirect.aspx?pid=7424&bid=1523&clickid=email-202401010000-undefined-undefined-0-email-ca-{{subscriber.uuid}}-luckydays-undefined-trickyspins_email_newbase
#
#             You received this message because you have subscribed to TrickySpins.
# Learn more about the new offers, playing strategies and best practices!
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 57878731 fetched successfully!
# campaign is 57867108 and list is 6405738
# Ready to fight for the rewards?
#
#                         $250 + 100 free spins
#
# https://media.playamopartners.com/redirect.aspx?pid=149640&bid=2058&lpid=993&dynamic=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-bizzo-undefined-trickyspins_email_newbase
#
#             Ready to fight for the rewards?
#
# Then place bets in your favorite casino slots, get points and stay ahead of other players on the leaderboard.
# 100% Up to C$250 on your first deposit!
#
# https://media.playamopartners.com/redirect.aspx?pid=149640&bid=2058&lpid=993&dynamic=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-bizzo-undefined-trickyspins_email_newbase
#
# Stay the course for wins.
#
#
#             You received this message because you have subscribed to TrickySpins.
# Learn more about the new offers, playing strategies and best practices!
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 57867108 fetched successfully!
# campaign is 57787996 and list is 6405738
# $750 + 200 free spins
#
# https://nmn-bc-7s.lptrak.com/redirect.aspx?pid=2020877&lpid=14606&bid=6747&var2=email-202401010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-nomini-undefined-trickyspins_email_newbase
#
#             The story begins with your first deposit, where you can receive a huge bonus of up to $750 + 200 free spins
#
# https://nmn-bc-7s.lptrak.com/redirect.aspx?pid=2020877&lpid=14606&bid=6747&var2=email-202401010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-nomini-undefined-trickyspins_email_newbase
#  spread over your first three deposits. But wait, it doesn't stop there.Grab your extra chance with Bonus Crab!
#
#
#             You received this message because you have subscribed to TrickySpins.
# Learn more about the new offers, playing strategies and best practices!
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 57787996 fetched successfully!
# campaign is 57787938 and list is 6405738
# 100% up to 500 C$ +  100 free spins for Avalon:  The Lost Kingdom
#
# https://media.playamopartners.com/redirect.aspx?pid=136232&bid=2036&lpid=609&dynamic=email-202401010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-national-undefined-trickyspins_email_newbase
#
#             Get ready to reload, explore, and conquer!
#
# Turbo-charge your luck with a 100%
# first deposit bonus up to 500 С$ and 100 free spins
#
# https://media.playamopartners.com/redirect.aspx?pid=136232&bid=2036&lpid=609&dynamic=email-202401010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-national-undefined-trickyspins_email_newbase
#  on Avalon: The Lost Kingdom*. Are you ready to unlock the mystical secrets and big rewards? Then welcome to the winning team.
#
#             You received this message because you have subscribed to TrickySpins.
# Learn more about the new offers, playing strategies and best practices!
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 57787938 fetched successfully!
# campaign is 57787888 and list is 6405738
# Get up to $1500 in bonus cash + 100 spins!
#
# https://media.luckydaysaffiliates.com/redirect.aspx?pid=7424&bid=1523&clickid=email-202401010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-luckydays-undefined-trickyspins_email_newbase
#
#             Brace yourselves, because Lucky Days is offering an unparalleled deal that you simply can't resist!
#
# Get ready to be blown away, because we're giving you
#  a whopping $1500 for FREE!
#
# https://media.luckydaysaffiliates.com/redirect.aspx?pid=7424&bid=1523&clickid=email-202401010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-luckydays-undefined-trickyspins_email_newbase
#
# Yes, you read that right. Not only that, but we're also throwing in an extra 100 spins to take your gaming journey to unprecedented heights. It's like hitting the jackpot without even spinning the reels!
#
# But here's the catch, time is ticking, and this offer won't last forever. So why wait? Dive into the thrill right away and make the most of this amazing opportunity.
#
#             You received this message because you have subscribed to TrickySpins.
# Learn more about the new offers, playing strategies and best practices!
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 57787888 fetched successfully!
# campaign is 57711780 and list is 6405738
# Big May sprint 2024-05-01 - 2024-05-31
#
# https://record.joinaff.com/_GUtnFvlzSb3fjgRf_EGLtmNd7ZgqdRLk/11/?pg=2&payload=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-winlegends-undefined-trickyspins_email_newbase
#
#             Mark your calendars!
#
# https://record.joinaff.com/_GUtnFvlzSb3fjgRf_EGLtmNd7ZgqdRLk/11/?pg=2&payload=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-winlegends-undefined-trickyspins_email_newbase
#
#
# From May 1st to May 31st, it’s your chance to compete in the thrilling Big May Sprint Tournament! Dive into the excitement and showcase your skills against fellow players to win incredible prizes!
#
#             You received this message because you have subscribed to TrickySpins.
# Learn more about the new offers, playing strategies and best practices!
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 57711780 fetched successfully!
# campaign is 57664523 and list is 6405738
# 100% match up to C$10,000 plus 100 FREE SPINS
#
# https://zotatraff.com/gc7c40e0a?subid=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-zotabet-undefined-trickyspins_email_newbase
#
#             Get an incredible 100% match up to C$10,000 plus 100 FREE SPINS
#
# https://zotatraff.com/gc7c40e0a?subid=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-zotabet-undefined-trickyspins_email_newbase
#  on your first deposit!
#
# This is just the beginning of your thrilling ride at Zotabet Casino, where we believe in starting BIG.
#
#             You received this message because you have subscribed to TrickySpins.
# Learn more about the new offers, playing strategies and best practices!
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 57664523 fetched successfully!
# campaign is 57664374 and list is 6405738
# 50% Reload Bonus up to $300
#
# https://justcasino.info/k70096c5b?visit_id={clickid}&utm_source=aff&utm_medium=Masha&utm_campaign=CA&utm_id=Mailer&subid={sourceid}=email-202401010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-justcasino-undefined-trickyspins_email_newbase
#
#             Get ready to reload, explore, and conquer!
#
# Join us this Friday and boost your gaming journey with an exclusive offer.
# 50% Reload Bonus up to $300
#
# https://justcasino.info/k70096c5b?visit_id={clickid}&utm_source=aff&utm_medium=Masha&utm_campaign=CA&utm_id=Mailer&subid={sourceid}=email-202401010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-justcasino-undefined-trickyspins_email_newbase
#  on your Friday deposit!
# Use the Promo Code: POW50
# The bonus will be automatically added to your account when you deposit this Friday. Mark your calendar!
#
#             You received this message because you have subscribed to TrickySpins.
# Learn more about the new offers, playing strategies and best practices!
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 57664374 fetched successfully!
# campaign is 57664236 and list is 6405738
# Epic Wheel  Deposit: $100+  Reward: Up to $2,000 bonus code EPIC
#
# https://playluckywins.com/j59f1f278&clickID=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-luckywins-undefined-trickyspins_email_newbase
#
#             Every spin gives you a shot at winning up to $2,000!
#
# https://playluckywins.com/j59f1f278&clickID=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-luckywins-undefined-trickyspins_email_newbase
#
#
# Why wait? The fortune wheel is spinning and the prizes are dropping. Try your luck today and let the good times roll!
# Bonus Code: EPIC
#
#
#             You received this message because you have subscribed to TrickySpins.
# Learn more about the new offers, playing strategies and best practices!
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 57664236 fetched successfully!
# campaign is 57664136 and list is 6405738
# 100% deposit match and 100 free spins
#
# https://levelupromo.com/aad388087?click_id=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-levelup-undefined-trickyspins_email_newbase
#
#             Embark on the beginning of a grand adventure at LevelUp!
#
# A 100% deposit match and 100 free spins
#
# https://levelupromo.com/aad388087?click_id=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-levelup-undefined-trickyspins_email_newbase
#  set the course for excitement, doubling your chances to win.
#
# Enter code LVL1: Your key to unlocking the treasure.
#
#
#
#             You received this message because you have subscribed to TrickySpins.
# Learn more about the new offers, playing strategies and best practices!
#
#
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 57664136 fetched successfully!
# campaign is 57623872 and list is 6405738
# daily cashback 20%
#
# https://bingotraff.com/gd786bb1d?subid=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-bingobonga-undefined-trickyspins_email_newbase
#
#             Get ready to spin and win like never before at BingoBonga Casino!
#
# We're introducing our DAILY CASHBACK offer
#
# https://bingotraff.com/gd786bb1d?subid=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-bingobonga-undefined-trickyspins_email_newbase
#
# Get up to 20% back EVERY. SINGLE. DAY!
#
# https://bingotraff.com/gd786bb1d?subid=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-bingobonga-undefined-trickyspins_email_newbase
#
#
# Imagine, play your favorite games  and if luck doesn't quite swing your way, we've got your back with up to 20% cashback!
#
#
#             You received this message because you have subscribed to TrickySpins.
# Learn more about the new offers, playing strategies and best practices!
#
#
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 57623872 fetched successfully!
# campaign is 57608513 and list is 6405738
# Live cashback 25% up to $300!
#
# https://lunubetplay.com/j0bb92ed9?subid=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-lunubet-undefined-trickyspins_email_newbase
#
#             Make sure to join the action and take advantage of this great deal.
# Play any live casino game during the qualifying period and if luck isn’t on your side, we’ve got your back with up to $300
#
# https://lunubetplay.com/j0bb92ed9?subid=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-lunubet-undefined-trickyspins_email_newbase
# . Your next big win could be just around the corner.
#
#
#             You received this message because you have subscribed to TrickySpins.
# Learn more about the new offers, playing strategies and best practices!
#
# https://trickyspins.com
#
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 57608513 fetched successfully!
# campaign is 57623494 and list is 6405738
# MUSTANG WELCOME BONUS 50% bonus +  50 Free Spins up to C$1400
#
# https://record.joinaff.com/_McHs5wwlezlXj8bgQ-rdhWNd7ZgqdRLk/9/?pg=4&payload=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-smokace-undefined-trickyspins_email_newbase
#
#             Get ready to gallop towards thrilling wins with our Mustang Welcome Bonus at Smokace Casino!
#
# Special Offer Just for You:
# 50% Bonus
#
# https://record.joinaff.com/_McHs5wwlezlXj8bgQ-rdhWNd7ZgqdRLk/9/?pg=4&payload=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-smokace-undefined-trickyspins_email_newbase
#  on your first deposit
# 50 Free Spins
#
# https://record.joinaff.com/_McHs5wwlezlXj8bgQ-rdhWNd7ZgqdRLk/9/?pg=4&payload=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-smokace-undefined-trickyspins_email_newbase
#  to keep the excitement rolling
# Up to C$1400
#
# https://record.joinaff.com/_McHs5wwlezlXj8bgQ-rdhWNd7ZgqdRLk/9/?pg=4&payload=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-smokace-undefined-trickyspins_email_newbase
#  in bonuses waiting for you
# Kickstart your adventure at Smokace Casino with extra funds and spins to play your favorite slots and games.
#
#
#             You received this message because you have subscribed to TrickySpins.
# Learn more about the new offers, playing strategies and best practices!
#
# https://trickyspins.com
#
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 57623494 fetched successfully!
# campaign is 57608174 and list is 6405738
# Refferal program 200 free spins for a friend
#
# https://m.media13aff.com/Redirect.aspx?mid=68&sid=4303&affid=506&cid=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-cosmicslot-undefined-trickyspins_email_newbase
#
#             Get ready to embark on an interstellar adventure with Cosmic Slot
# Invite your friends to join the Cosmic Slot universe, and we'll thank you with an astronomical gift: 200 Free Spins
#
# https://m.media13aff.com/Redirect.aspx?mid=68&sid=4303&affid=506&cid=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-cosmicslot-undefined-trickyspins_email_newbase
#  for each friend who signs up and makes their first deposit.
#
#
#             You received this message because you have subscribed to TrickySpins.
# Learn more about the new offers, playing strategies and best practices!
#
# https://trickyspins.com
#
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 57608174 fetched successfully!
# campaign is 57602267 and list is 6405738
# Crypto Welcome Offer up to 100 mBTC +100 free spins + 1 bonus crab
#
# https://media.rabona.com/redirect.aspx?pid=2044557&lpid=14765&bid=6968&var2=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-rabona-undefined-trickyspins_email_newbase
#
#             Get ready to boost your balance with up to 100 mBTC
#
# https://media.rabona.com/redirect.aspx?pid=2044557&lpid=14765&bid=6968&var2=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-rabona-undefined-trickyspins_email_newbase
#
# on your first deposit!
#
# https://media.rabona.com/redirect.aspx?pid=2044557&lpid=14765&bid=6968&var2=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-rabona-undefined-trickyspins_email_newbase
#
#
# This generous bonus is designed to extend your playtime and enhance your chances of hitting those big wins.
#
#             You received this message because you have subscribed to TrickySpins.
#
# https://trickyspins.com/
#
# Learn more about the new offers, playing strategies and best practices!
#
# https://trickyspins.com/
#
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 57602267 fetched successfully!
# campaign is 57602268 and list is 6405738
# Crypto Welcome Offer up to 100 mBTC +100 free spins + 1 bonus crab
#
# https://media.rabona.com/redirect.aspx?pid=2044557&lpid=14765&bid=6968&var2=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-rabona-undefined-trickyspins_email_newbase
#
#             Get ready to boost your balance with up to 100 mBTC
#
# https://media.rabona.com/redirect.aspx?pid=2044557&lpid=14765&bid=6968&var2=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-rabona-undefined-trickyspins_email_newbase
#
# on your first deposit!
#
# https://media.rabona.com/redirect.aspx?pid=2044557&lpid=14765&bid=6968&var2=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-rabona-undefined-trickyspins_email_newbase
#
#
# This generous bonus is designed to extend your playtime and enhance your chances of hitting those big wins.
#
#             You received this message because you have subscribed to TrickySpins.
#
# https://trickyspins.com/
#
# Learn more about the new offers, playing strategies and best practices!
#
# https://trickyspins.com/
#
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 57602268 fetched successfully!
# campaign is 57584060 and list is 6405738
# SpinAway with 10 free spins per day in Big Bass Bonanza.
#
# https://media.spinawaypartners.com/redirect.aspx?pid=3353&lpid=6&bid=1476&subid=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-spinaway-undefined-trickyspins_email_newbase
#
#             Collect 100 Free Spins Right After Your First Deposit!
#
# https://media.spinawaypartners.com/redirect.aspx?pid=3353&lpid=6&bid=1476&subid=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-spinaway-undefined-trickyspins_email_newbase
#
#
# Yes, you read that right! Make your first deposit with us and unlock a treasure chest of 100 free spins. But that's not all - we're spreading the joy to ensure your adventure keeps getting better day by day.
#
#
#             You received this message because you have subscribed to TrickySpins.
#
# https://trickyspins.com/
#
# Learn more about the new offers, playing strategies and best practices!
#
# https://trickyspins.com/
#
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 57584060 fetched successfully!
# campaign is 57523305 and list is 6405738
# Stock Market new game!
#
# https://m.media13aff.com/Redirect.aspx?mid=100&sid=4316&affid=506&cid=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-spinbro-undefined-trickyspins_email_newbase
#
#             We're thrilled to introduce the latest addition to Evolution's gaming lineup - "Stock Market"!
#
# This exhilarating new game combines the thrill of financial markets with the strategic depth of a top-tier gaming experience, offering you a unique opportunity to test your prediction skills and grow your virtual portfolio.
# Predict a stock's rise, and if it climbs by 50%, you pocket a 50% gain on your portfolio.
#
# https://m.media13aff.com/Redirect.aspx?mid=100&sid=4316&affid=506&cid=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-spinbro-undefined-trickyspins_email_newbase
#
# It's a battleground for the financially savvy, a playground for strategists, and a proving ground for aspiring moguls. Ready to make your mark in the virtual financial world and skyrocket your portfolio through a series of successful forecasts?
#
#
#             You received this message because you have subscribed to TrickySpins.
#
# https://trickyspins.com/
#
# Learn more about the new offers, playing strategies and best practices!
#
# https://trickyspins.com/
#
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 57523305 fetched successfully!
# campaign is 57523303 and list is 6405738
# Stock Market new game!
#
# https://m.media13aff.com/Redirect.aspx?mid=100&sid=4316&affid=506&cid=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-spinbro-undefined-trickyspins_email_newbase
#
#             We're thrilled to introduce the latest addition to Evolution's gaming lineup - "Stock Market"!
#
# This exhilarating new game combines the thrill of financial markets with the strategic depth of a top-tier gaming experience, offering you a unique opportunity to test your prediction skills and grow your virtual portfolio.
# Predict a stock's rise, and if it climbs by 50%, you pocket a 50% gain on your portfolio.
#
# https://m.media13aff.com/Redirect.aspx?mid=100&sid=4316&affid=506&cid=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-spinbro-undefined-trickyspins_email_newbase
#
# It's a battleground for the financially savvy, a playground for strategists, and a proving ground for aspiring moguls. Ready to make your mark in the virtual financial world and skyrocket your portfolio through a series of successful forecasts?
#
#
#             You received this message because you have subscribed to TrickySpins.
#
# https://trickyspins.com/
#
# Learn more about the new offers, playing strategies and best practices!
#
# https://trickyspins.com/
#
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 57523303 fetched successfully!
# campaign is 57521781 and list is 6405738
# Easter quest daily prize calendar
#
# https://media.rabona.com/redirect.aspx?pid=2044557&lpid=14765&bid=6968&var2=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-rabona-undefined-trickyspins_email_newbase
#
#             Forget the chocolate hunt!
#
# Unlock thrilling daily missions for a chance to win cash rewards, free spins, and special bonuses.
# Let the Easter Quest begin!
#
# https://media.rabona.com/redirect.aspx?pid=2044557&lpid=14765&bid=6968&var2=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-rabona-undefined-trickyspins_email_newbase
#
#
#
#             You received this message because you have subscribed to TrickySpins.
# Learn more about the new offers, playing strategies and best practices!
#
# https://trickyspins.com/
#
#
#
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 57521781 fetched successfully!
# campaign is 57502064 and list is 6405738
# revenge bonus 15% bonus, reaching up to C$1400!
#
# https://record.joinaff.com/_McHs5wwleznXv1vJGjPvZWNd7ZgqdRLk/14/?pg=5&payload=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-windetta-undefined-trickyspins_email_newbase
#
# Are you ready to turn the tables and get your sweet revenge?
# Windetta Casino invites you to unleash your winning spirit with our exclusive Revenge 15% Bonus offer! This is your chance to boost each of your deposits with a fantastic
# 15% bonus, reaching up to C$1400.
#
# https://record.joinaff.com/_McHs5wwleznXv1vJGjPvZWNd7ZgqdRLk/14/?pg=5&payload=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-windetta-undefined-trickyspins_email_newbase
#
#             You received this message because you have subscribed to TrickySpins.
#
# https://trickyspins.com
#
# Learn more about the new offers, playing strategies and best practices!
#
# https://trickyspins.com/
#
#
#
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 57502064 fetched successfully!
# campaign is 57473242 and list is 6405738
# Crazy crypto tuesday 100% bonus on all crypto deposits
#
# https://luckydreams.info/k65af60a3?visit_id={clickid}&utm_source=aff&utm_medium=Masha&utm_campaign=CA&utm_id=Mailer&subid={sourceid}=email-202401010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-luckydreams-undefined-trickyspins_email_newbase
#
#             Make sure to mark your calendar and get ready to boost your gaming adventure!
#
# Get a 100% bonus on ALL your cryptocurrency deposits.
#
# https://luckydreams.info/k65af60a3?visit_id={clickid}&utm_source=aff&utm_medium=Masha&utm_campaign=CA&utm_id=Mailer&subid={sourceid}=email-202401010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-luckydreams-undefined-trickyspins_email_newbase
#  That's right - every crypto deposit you make this Tuesday will be matched by us. Whether you're a Bitcoin enthusiast, an Ethereum advocate, or a fan of other cryptocurrencies, your deposits will take you twice as far!
# Enter the special code: CRYPTO in the bonus code field.
#
#             You received this message because you have subscribed to TrickySpins.
#
# https://trickyspins.com
#
# Learn more about the new offers, playing strategies and best practices!
#
# https://trickyspins.com/
#
#
#
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 57473242 fetched successfully!
# campaign is 57461622 and list is 6405738
# Welcome Bonus Up to C$10,000 + 100 Free Spins!
#
# https://zotatraff.com/gc7c40e0a?subid=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-zotabet-undefined-trickyspins_email_newbase
#
# Step into a world where excitement knows no bounds and every moment is a chance to win big!
# We're thrilled to welcome you to ZotaBet Casino, where your adventure begins with an extraordinary Welcome Offer crafted just for you.
# Unlock Your 100% Welcome Bonus Up to C$10,000 + 100 Free Spins!
#
# https://zotatraff.com/gc7c40e0a?subid=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-zotabet-undefined-trickyspins_email_newbase
#
#
#
#             You received this message because you have subscribed to TrickySpins.
#
# https://trickyspins.com
#
# Learn more about the new offers, playing strategies and best practices!
#
# https://trickyspins.com/
#
#
#
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 57461622 fetched successfully!
# campaign is 57445083 and list is 6405738
# Welcome bonus 100% up to 750$ + 200 free spins+ 1 bonus crab
#
# https://lunubetplay.com/j0bb92ed9?subid=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-lunubet-undefined-trickyspins_email_newbase
#
# TrickySpins is a treasure trove of secret offers and exclusive deals designed just for you!
# Step into the world of endless excitement and opportunities
# at Lunubet Casino!
#
# https://lunubetplay.com/j0bb92ed9?subid=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-lunubet-undefined-trickyspins_email_newbase
#  We're thrilled to roll out the red carpet for you with an exclusive welcome offer that's too good to pass up:
# 100% up to 750$ + 200 free spins + 1 bonus crab!
#
# https://lunubetplay.com/j0bb92ed9?subid=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-lunubet-undefined-trickyspins_email_newbase
#
# Double your fun and double your chances right from the start.
#
#
#             You received this message because you have subscribed to TrickySpins.
#
# https://trickyspins.com
#
# Learn more about the new offers, playing strategies and best practices!
#
# https://trickyspins.com/
#
#
#
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 57445083 fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6405739/campaigns?ws.op=find&campaign_type=b&ws.start=0&ws.size=30
# Campaigns fetched successfully!
# campaign is 57994303 and list is 6405739
# Unleash Fiery Fortunes with Coin Volcano
#
#                         Coin Volcano highest RTP
#
# https://m.media13aff.com/Redirect.aspx?mid=112&sid=43014&affid=506&cid=email-202301010000-undefined-undefined-0-email-au-xxxxxxxxxxxxxxxx-spinbro-undefined-trickyspins_email_newbase
#
#             Get ready for an explosive adventure with Coin Volcano, the latest 3x3 reel game by Booongo!
#
# Featuring the thrilling hold & win bonus game and the enhanced ultra bonus game, this high RTP slot
#
# https://m.media13aff.com/Redirect.aspx?mid=112&sid=43014&affid=506&cid=email-202301010000-undefined-undefined-0-email-au-xxxxxxxxxxxxxxxx-spinbro-undefined-trickyspins_email_newbase
#  promises endless excitement.
#
# Watch as reels erupt with coins, volcano multipliers, and four fiery jackpots. trigger the bonus game with three symbols on the middle reel, and enjoy respins that reset with every new symbol. Look out for the scorching ball, which collects all coin and jackpot values in view.
#
#
#             You received this message because you have subscribed to TrickySpins.
# Learn more about the new offers, playing strategies and best practices!
#
# https://trickyspins.com/au/home
#
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 57994303 fetched successfully!
# campaign is 57960970 and list is 6405739
# Unleash Fiery Fortunes with Coin Volcano
#
#                         Coin Volcano highest RTP
#
# https://m.media13aff.com/Redirect.aspx?mid=112&sid=43014&affid=506&cid=email-202301010000-undefined-undefined-0-email-au-xxxxxxxxxxxxxxxx-spinbro-undefined-trickyspins_email_newbase
#
#             Get ready for an explosive adventure with Coin Volcano, the latest 3x3 reel game by Booongo!
#
# Featuring the thrilling hold & win bonus game and the enhanced ultra bonus game, this high RTP slot
#
# https://m.media13aff.com/Redirect.aspx?mid=112&sid=43014&affid=506&cid=email-202301010000-undefined-undefined-0-email-au-xxxxxxxxxxxxxxxx-spinbro-undefined-trickyspins_email_newbase
#  promises endless excitement.
#
# Watch as reels erupt with coins, volcano multipliers, and four fiery jackpots. trigger the bonus game with three symbols on the middle reel, and enjoy respins that reset with every new symbol. Look out for the scorching ball, which collects all coin and jackpot values in view.
#
#
#             You received this message because you have subscribed to TrickySpins.
# Learn more about the new offers, playing strategies and best practices!
#
# https://trickyspins.com/au/home
#
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 57960970 fetched successfully!
# campaign is 57914169 and list is 6405739
# Referral programm
#
#                         Refferal program 200 free spins for a friend
#
# https://m.media13aff.com/Redirect.aspx?mid=53&sid=4305&affid=506&cid=email-202301010000-undefined-undefined-0-email-au-xxxxxxxxxxxxxxxx-cosmicslot-undefined-trickyspins_email_newbase
#
#             Get ready to embark on an interstellar adventure with Cosmic Slot
# Invite your friends to join the Cosmic Slot universe, and we'll thank you with an astronomical gift: 200 Free Spins
#
# https://m.media13aff.com/Redirect.aspx?mid=53&sid=4305&affid=506&cid=email-202301010000-undefined-undefined-0-email-au-xxxxxxxxxxxxxxxx-cosmicslot-undefined-trickyspins_email_newbase
#  for each friend who signs up and makes their first deposit.
#
#
#
#
#             You received this message because you have subscribed to TrickySpins.
# Learn more about the new offers, playing strategies and best practices!
#
# https://trickyspins.com/au/home
#
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 57914169 fetched successfully!
# campaign is 57914153 and list is 6405739
# 100% Welcome Bonus Up to A$10,000 + 100 Free Spins!
#
#                         Welcome Bonus Up to A$10,000 + 100 Free Spins!
#
# https://zotatraff.com/gc1473870?subid=email-202301010000-undefined-undefined-0-email-au-xxxxxxxxxxxxxxxx-zotabet-undefined-trickyspins_email_newbase
#
# ...
# DISCLAIMER: Não somos uma operadora de jogos de azar. Nosso serviço consiste em descobrir, comparar e negociar as melhores ofertas disponíveis para nossos assinantes. As ofertas de boas-vindas são apenas para novos jogadores. Aplicam-se termos e condições. 18+ Apoiamos o jogo responsável. Estamos aqui para ajudá-lo a manter o controle e garantir que o jogo continue sendo uma experiência agradável.
# Details for campaign 57648950 fetched successfully!
# campaign is 57609038 and list is 6456354
# CASHBACK
#
# https://wzbw.servclick1move.com/?mid=107229_905045&var2=email-202301010000-undefined-undefined-0-email-nz-xxxxxxxxxxxxxxxx-wazamba-undefined-trickyspins_email_newbase
#
#             Ganhe muito com os bônus do TruckySpins!
#
# Estamos turbinando seu jogo com uma oferta exclusiva de CASHBACK
#
# https://wzbw.servclick1move.com/?mid=107229_905045&var2=email-202301010000-undefined-undefined-0-email-nz-xxxxxxxxxxxxxxxx-wazamba-undefined-trickyspins_email_newbase
# que é boa demais para deixar passar. Jogue seus jogos favoritos e receba uma generosa porcentagem de volta de suas perdas líquidas. É a nossa maneira de dizer obrigado por jogar conosco.
#
#
#             Você recebeu esta mensagem porque se inscreveu no TrickySpins.
# Saiba mais sobre as novas ofertas, estratégias de jogo e práticas recomendadas!
#
#
# DISCLAIMER: Não somos uma operadora de jogos de azar. Nosso serviço consiste em descobrir, comparar e negociar as melhores ofertas disponíveis para nossos assinantes. As ofertas de boas-vindas são apenas para novos jogadores. Aplicam-se termos e condições. 18+
# Apoiamos o jogo responsável. Estamos aqui para ajudá-lo a manter o controle e garantir que o jogo continue sendo uma experiência agradável.
# Details for campaign 57609038 fetched successfully!
# campaign is 57589207 and list is 6456354
# liga blackjack 3,185,00 EUR
#
# https://bnkw.servclick1move.com/?mid=107229_905077&var2=email-202301010000-undefined-undefined-0-email-br-xxxxxxxxxxxxxxxx-bankonbet-undefined-trickyspins_email_newbase
#
#             Liga Blackjack, com um prêmio de cair o queixo de 3.185.000 euros!
#
# https://bnkw.servclick1move.com/?mid=107229_905077&var2=email-202301010000-undefined-undefined-0-email-br-xxxxxxxxxxxxxxxx-bankonbet-undefined-trickyspins_email_newbase
#  Este é o seu bilhete de ouro para entrar no eletrizante mundo do blackjack, onde a habilidade e a sorte podem lhe render ganhos incríveis.
#
#
# Você recebeu esta mensagem porque se inscreveu no TrickySpins.
# Saiba mais sobre as novas ofertas, estratégias de jogo e práticas recomendadas!
#
# https://trickyspins.com/
#
#
#
# DISCLAIMER: Não somos uma operadora de jogos de azar. Nosso serviço é descobrir, comparar e negociar as melhores ofertas disponíveis para nossos assinantes. As ofertas de boas-vindas são apenas para novos jogadores. Aplicam-se termos e condições. 18+
# Apoiamos o jogo responsável. Estamos aqui para ajudá-lo a manter o controle e garantir que o jogo continue sendo uma experiência agradável.
# Details for campaign 57589207 fetched successfully!
# campaign is 57541811 and list is 6456354
# 100% até R$5500
#
# https://go.bet90partners.com/visit/?bta=800563&nci=5564&afp=email-202301010000-undefined-undefined-0-email-br-xxxxxxxxxxxxxxxx-spinbookie-undefined-trickyspins_email_newbase
#
#             Nossa oferta de recarga de 100% é o que você precisa para a Páscoa!
# Ganhe dois Bônus de Recarga de 100% até R$5500
#
# https://go.bet90partners.com/visit/?bta=800563&nci=5564&afp=email-202301010000-undefined-undefined-0-email-br-xxxxxxxxxxxxxxxx-spinbookie-undefined-trickyspins_email_newbase
# , simplesmente depositando R$160+ duas vezes no mesmo dia!
#
#             Você recebeu esta mensagem porque se inscreveu no TrickySpins.
# Saiba mais sobre as novas ofertas, estratégias de jogo e práticas recomendadas!
#
#
# DISCLAIMER: Não somos uma operadora de jogos de azar. Nosso serviço consiste em descobrir, comparar e negociar as melhores ofertas disponíveis para nossos assinantes. As ofertas de boas-vindas são apenas para novos jogadores. Aplicam-se termos e condições. 18+
# Apoiamos o jogo responsável. Estamos aqui para ajudá-lo a manter o controle e garantir que o jogo continue sendo uma experiência agradável.
# Details for campaign 57541811 fetched successfully!
# campaign is 57501997 and list is 6456354
# Bônus de Boas-Vindas de criptografia  Até 100 mBTC +  100  Rodadas Grátis
#
# https://sgc.servclick1move.com/?mid=107229_931845&var2=email-202401010000-undefined-undefined-0-email-br-xxxxxxxxxxxxxxxx-sgcasino-undefined-trickyspins_email_newbase
#
# Saudações calorosas do SG Casino - seu principal destino para experiências de jogo emocionantes!
# Apresentamos nosso Bônus de Boas-Vindas de Criptomoedas: Ganhe até 100 mBTC mais 100 Rodadas Grátis
#
# https://sgc.servclick1move.com/?mid=107229_931845&var2=email-202401010000-undefined-undefined-0-email-br-xxxxxxxxxxxxxxxx-sgcasino-undefined-trickyspins_email_newbase
#  para começar sua aventura com estilo. Nós abraçamos de braços abertos o futuro dos jogos. É por isso que aceitamos uma grande variedade de criptomoedas para esta oferta, incluindo Bitcoin, Bitcoin Cash, Tether (USDT), Litecoin, Ethereum, Ripple, USD Coin e DAI. O poder de escolha está em suas mãos!
#
#
# https://www.trickyspins.com
#
#             Você recebeu esta mensagem porque se inscreveu no TrickySpins.
# Saiba mais sobre as novas ofertas, estratégias de jogo e práticas recomendadas!
# DISCLAIMER: Não somos uma operadora de jogos de azar. Nosso serviço consiste em descobrir, comparar e negociar as melhores ofertas disponíveis para nossos assinantes. As ofertas de boas-vindas são apenas para novos jogadores. Aplicam-se termos e condições. 18+ Apoiamos o jogo responsável. Estamos aqui para ajudá-lo a manter o controle e garantir que o jogo continue sendo uma experiência agradável.
# Details for campaign 57501997 fetched successfully!
# campaign is 57473520 and list is 6456354
# 5% de cashback toda semana até R$1.000
#
# https://record.qbetpartners.com/_LcUWE23I2SxS0ellEXRNxWNd7ZgqdRLk/4/?pg=2?payload=email-202301010000-undefined-undefined-0-email-br-xxxxxxxxxxxxxxxx-qbet-undefined-trickyspins_email_newbase
#
#             Prepare-se para mergulhar no mundo vibrante e ilimitado do Cassino ao Vivo com a nossa oferta exclusiva de Cashback Semanal, uma oportunidade única de aumentar suas chances e seu saldo! No QBet Casino, estamos sempre buscando maneiras de recompensar nossos jogadores mais dedicados, e é com grande entusiasmo que apresentamos nossa mais recente promoção: 5% de Cashback em todos os jogos do cassino ao vivo!
#
# https://record.qbetpartners.com/_LcUWE23I2SxS0ellEXRNxWNd7ZgqdRLk/4/?pg=2?payload=email-202301010000-undefined-undefined-0-email-br-xxxxxxxxxxxxxxxx-qbet-undefined-trickyspins_email_newbase
#
#
#
#             Você recebeu esta mensagem porque se inscreveu no TrickySpins.
# Saiba mais sobre as novas ofertas, estratégias de jogo e práticas recomendadas!
# DISCLAIMER: Não somos uma operadora de jogos de azar. Nosso serviço consiste em descobrir, comparar e negociar as melhores ofertas disponíveis para nossos assinantes. As ofertas de boas-vindas são apenas para novos jogadores. Aplicam-se termos e condições. 18+ Apoiamos o jogo responsável. Estamos aqui para ajudá-lo a manter o controle e garantir que o jogo continue sendo uma experiência agradável.
# Details for campaign 57473520 fetched successfully!
# campaign is 57419236 and list is 6456354
# PROGRAMA VIP
#
# https://wzbw.servclick1move.com/?mid=107229_905045&var2=email-202301010000-undefined-undefined-0-email-nz-xxxxxxxxxxxxxxxx-wazamba-undefined-trickyspins_email_newbase
#
#             Melhore seu jogo com o TrickySpins VIP!
#
# https://wzbw.servclick1move.com/?mid=107229_905045&var2=email-202301010000-undefined-undefined-0-email-nz-xxxxxxxxxxxxxxxx-wazamba-undefined-trickyspins_email_newbase
#
# Recompensas exclusivas, bônus personalizados e suporte prioritário o aguardam. Junte-se à elite - gire, ganhe e desfrute de um luxo sem igual. Continue jogando seus jogos favoritos e nós o notificaremos quando você se qualificar. Isso é mais do que um programa; é a nossa maneira de agradecer por sua fidelidade. Faça o upgrade agora!
#
#
#             Você recebeu esta mensagem porque se inscreveu no TrickySpins.
# Saiba mais sobre as novas ofertas, estratégias de jogo e práticas recomendadas!
# DISCLAIMER: Não somos uma operadora de jogos de azar. Nosso serviço consiste em descobrir, comparar e negociar as melhores ofertas disponíveis para nossos assinantes. As ofertas de boas-vindas são apenas para novos jogadores. Aplicam-se termos e condições. 18+ Apoiamos o jogo responsável. Estamos aqui para ajudá-lo a manter o controle e garantir que o jogo continue sendo uma experiência agradável.
#
#
# https://www.trickyspins.com
# Details for campaign 57419236 fetched successfully!
# campaign is 57460345 and list is 6456354
# Festival de Prêmios
#
# https://record.ibetaffiliates.com/_EEcsKdwcyyrITHy77psZsWNd7ZgqdRLk/7/?pg=4?payload=email-202301010000-undefined-undefined-0-email-no-xxxxxxxxxxxxxxxx-ibet-undefined-trickyspins_email_newbase
#
#             Prepare-se para a maior celebração de jogos que voce ja viu, pois trazemos até você o Festival de Prêmios, uma promoção espetacular feita sob medida para nossos clientes brasileiros!
# Com um incrível prêmio total de R$2.000.000,00.
#
# https://record.ibetaffiliates.com/_EEcsKdwcyyrITHy77psZsWNd7ZgqdRLk/7/?pg=4?payload=email-202301010000-undefined-undefined-0-email-no-xxxxxxxxxxxxxxxx-ibet-undefined-trickyspins_email_newbase
#  Este é o seu bilhete de ouro para um jogo emocionante e recompensas incríveis.
#
#
#             Você recebeu esta mensagem porque se inscreveu no TrickySpins.
# Saiba mais sobre as novas ofertas, estratégias de jogo e práticas recomendadas!
# DISCLAIMER: Não somos uma operadora de jogos de azar. Nosso serviço consiste em descobrir, comparar e negociar as melhores ofertas disponíveis para nossos assinantes. As ofertas de boas-vindas são apenas para novos jogadores. Aplicam-se termos e condições. 18+ Apoiamos o jogo responsável. Estamos aqui para ajudá-lo a manter o controle e garantir que o jogo continue sendo uma experiência agradável.
# Details for campaign 57460345 fetched successfully!
# campaign is 57432156 and list is 6456354
# Sábados de recarga
#
# https://go.bet90partners.com/visit/?bta=800563&nci=5564&afp=email-202301010000-undefined-undefined-0-email-br-xxxxxxxxxxxxxxxx-spinbookie-undefined-trickyspins_email_newbase
#
#             Preparado para elevar o seu fim de semana a outro nível?
#
# O Spinbookie Casino tem o prazer de apresentar nossa oferta exclusiva: Sábados de Recarga! Aproveite 50% de bônus até R$8000
#
# https://go.bet90partners.com/visit/?bta=800563&nci=5564&afp=email-202301010000-undefined-undefined-0-email-br-xxxxxxxxxxxxxxxx-spinbookie-undefined-trickyspins_email_newbase
#  em seus depósitos de sábado e dê aquele impulso extra à sua diversão. É a oportunidade perfeita para jogar seus slots e jogos de mesa favoritos com muito mais crédito!
#
#
#             Você recebeu esta mensagem porque se inscreveu no TrickySpins.
# Saiba mais sobre as novas ofertas, estratégias de jogo e práticas recomendadas!
#
#
# DISCLAIMER: Não somos uma operadora de jogos de azar. Nosso serviço consiste em descobrir, comparar e negociar as melhores ofertas disponíveis para nossos assinantes. As ofertas de boas-vindas são apenas para novos jogadores. Aplicam-se termos e condições. 18+
# Apoiamos o jogo responsável. Estamos aqui para ajudá-lo a manter o controle e garantir que o jogo continue sendo uma experiência agradável.
# Details for campaign 57432156 fetched successfully!
# campaign is 57396779 and list is 6456354
# CASHBACK
#
# https://wzbw.servclick1move.com/?mid=107229_905045&var2=email-202301010000-undefined-undefined-0-email-nz-xxxxxxxxxxxxxxxx-wazamba-undefined-trickyspins_email_newbase
#
#             Ganhe muito com os bônus do TruckySpins!
#
# Estamos turbinando seu jogo com uma oferta exclusiva de CASHBACK
#
# https://wzbw.servclick1move.com/?mid=107229_905045&var2=email-202301010000-undefined-undefined-0-email-nz-xxxxxxxxxxxxxxxx-wazamba-undefined-trickyspins_email_newbase
# que é boa demais para deixar passar. Jogue seus jogos favoritos e receba uma generosa porcentagem de volta de suas perdas líquidas. É a nossa maneira de dizer obrigado por jogar conosco.
#
#
#             Você recebeu esta mensagem porque se inscreveu no TrickySpins.
# Saiba mais sobre as novas ofertas, estratégias de jogo e práticas recomendadas!
#
#
# DISCLAIMER: Não somos uma operadora de jogos de azar. Nosso serviço consiste em descobrir, comparar e negociar as melhores ofertas disponíveis para nossos assinantes. As ofertas de boas-vindas são apenas para novos jogadores. Aplicam-se termos e condições. 18+
# Apoiamos o jogo responsável. Estamos aqui para ajudá-lo a manter o controle e garantir que o jogo continue sendo uma experiência agradável.
# Details for campaign 57396779 fetched successfully!
# campaign is 57391939 and list is 6456354
# bônus de boas-vindas
#
# https://bnkw.servclick1move.com/?mid=107229_905077&var2=email-202301010000-undefined-undefined-0-email-br-xxxxxxxxxxxxxxxx-bankonbet-undefined-trickyspins_email_welcome
#
#
# Prepare-se para se surpreender com nossos insights, bônus e ofertas de primeira linha dos principais cassinos do setor.
# Como membro, você será o primeiro a desfrutar de ofertas e promoções exclusivas que não encontrará em nenhum outro lugar.
# Prepare-se para uma experiência de jogo como nenhuma outra!
#
#
#
# Você recebeu esta mensagem porque se inscreveu no TrickySpins.
# Saiba mais sobre as novas ofertas, estratégias de jogo e práticas recomendadas!
#
# https://trickyspins.com/
#
#
#
# DISCLAIMER: Não somos uma operadora de jogos de azar. Nosso serviço é descobrir, comparar e negociar as melhores ofertas disponíveis para nossos assinantes. As ofertas de boas-vindas são apenas para novos jogadores. Aplicam-se termos e condições. 18+
# Apoiamos o jogo responsável. Estamos aqui para ajudá-lo a manter o controle e garantir que o jogo continue sendo uma experiência agradável.
# Details for campaign 57391939 fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6498565/campaigns?ws.op=find&campaign_type=b&ws.start=0&ws.size=30
# Campaigns fetched successfully!
# campaign is 56647645 and list is 6498565
# Logo
#
# http://www.aweber.com
#
#
#
#                         Loyalty prorgamm 7% Cosmic Coins for each deposit
#
# https://m.media13aff.com/Redirect.aspx?mid=53&sid=4305&affid=506&cid=email-202301010000-undefined-undefined-0-email-au-xxxxxxxxxxxxxxxx-cosmicslot-undefined-trickyspins_email
#
#             CosmicSlot is a preferred destination for players who want to feel the excitement from the best slot games.
# Don’t miss a unique opportunity of getting an adorable bonus, which we have prepared for you today.
# Grab it and have fun playing!
#
#                                 I'm in!
#
# https://m.media13aff.com/Redirect.aspx?mid=53&sid=4305&affid=506&cid=email-202301010000-undefined-undefined-0-email-au-xxxxxxxxxxxxxxxx-cosmicslot-undefined-trickyspins_email
#
#                         Coins can be redeemed for bonuses or free spins in the bonus store.
#
# https://m.media13aff.com/Redirect.aspx?mid=53&sid=4305&affid=506&cid=email-202301010000-undefined-undefined-0-email-au-xxxxxxxxxxxxxxxx-cosmicslot-undefined-trickyspins_email
#
#             You received this message because you have subscribed to TrickySpins.
#
# https://trickyspins.com/au/home
#
# Learn more about the new offers, playing strategies and best practices!
#
# https://trickyspins.com/au/home
#
#
#
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 56647645 fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6679170/campaigns?ws.op=find&campaign_type=b&ws.start=0&ws.size=30
# Campaigns fetched successfully!

# %%
#campaign_characteristics[5]

# %%
if __name__ == "__main__":
    load_data_to_db(json_vector=campaign_characteristics, schema='danila', table='stg_aweber__campaign_characteristics')
