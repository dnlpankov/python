# %%
import os
os.environ['OAUTHLIB_INSECURE_TRANSPORT'] = '1'

from datetime import datetime
import pytz

import os
import json
import requests
from requests_oauthlib import OAuth2Session
from datetime import datetime
from urllib.parse import urlencode
import pandas as pd
import re
import time

# %%
creds_path="./"
test=0
#test=1
if test==1:
    limit_per_request=1
    sleep_time_for_one_campaign=0
    creds_path="./"
else:
    limit_per_request=30
    sleep_time_for_one_campaign=0.6
    creds_path="/home/deploy/python/aweber/"

# %%
# Path to Aweber credentials file
aweber_creds = creds_path+ 'aweber_credentials.json'

# Load the credentials
with open(aweber_creds, 'r') as file:
    credentials = json.load(file)


# Assign creds to variables
client_id = credentials['client_id']
client_secret = credentials['client_secret']
redirect_uri = 'http://localhost:5000/oauth/callback'

# OAuth2 endpoints
authorization_base_url = 'https://auth.aweber.com/oauth2/authorize'
token_url = 'https://auth.aweber.com/oauth2/token'

# Scopes
scopes = ['email.read', 'account.read', 'list.read', 'subscriber.read']

# File to store tokens
token_file = creds_path+'aweber_tokens.json'

def save_tokens(tokens):
    with open(token_file, 'w') as f:
        json.dump(tokens, f)

def load_tokens():
    if os.path.exists(token_file):
        with open(token_file, 'r') as f:
            return json.load(f)
    return None

def refresh_tokens(refresh_token):
    extra = {'client_id': client_id, 'client_secret': client_secret}
    aweber = OAuth2Session(client_id, token={'refresh_token': refresh_token}, auto_refresh_kwargs=extra, auto_refresh_url=token_url, token_updater=save_tokens)
    tokens = aweber.refresh_token(token_url, refresh_token=refresh_token)
    save_tokens(tokens)
    return tokens

def get_aweber_session():
    tokens = load_tokens()
    
    if tokens is None:
        raise Exception("No tokens found. Please run the initial setup script first.")
    
    # Check if token has expired
    expiration_time = datetime.fromtimestamp(tokens['expires_at'])
    if datetime.now() >= expiration_time:
        tokens = refresh_tokens(tokens['refresh_token'])
    
    return OAuth2Session(client_id, token=tokens, scope=scopes), tokens['access_token']

def get_campaigns(list_id, account_id, campaign_type, start=0, limit=1000):
    aweber, access_token = get_aweber_session()
    try:
        params = {'ws.op': 'find', 'campaign_type': campaign_type, 'ws.start': start, 'ws.size': limit}
        campaigns_url = f'https://api.aweber.com/1.0/accounts/{account_id}/lists/{list_id}/campaigns?{urlencode(params)}'
        headers = {
            'Accept': 'application/json',
            'User-Agent': 'AWeber-Python-code-sample/1.0',
            'Authorization': f'Bearer {access_token}'
        }
        print(f"Fetching campaigns with URL: {campaigns_url}")
        response = aweber.get(campaigns_url, headers=headers)
        response.raise_for_status()
        campaigns = response.json()
        print("Campaigns fetched successfully!")
        return campaigns
    except requests.exceptions.RequestException as e:
        print(f"Error fetching campaigns for list {list_id}:", e)
        return {'entries': []}
# Function to convert iso format time to CET
def convert_to_cet(time_str):
    #print(time_str)
    time_str_cet=None
    if time_str is not None:
        input_time = datetime.fromisoformat(time_str)
        cet_tz = pytz.timezone("Europe/Berlin")
        cet_time = input_time.astimezone(cet_tz)
        time_str_cet=cet_time.strftime('%Y-%m-%d %H:%M:%S')
    return time_str_cet

def get_all_lists_for_account(account_id):
    # response = requests.get(f'https://api.aweber.com/1.0/accounts/{account_id}/lists', headers=headers)
    # lists = response.json()
    try:
        aweber, access_token = get_aweber_session()
        #print(access_token)
        lists_url = f'https://api.aweber.com/1.0/accounts/{account_id}/lists'
        headers = {
            'Accept': 'application/json',
            'User-Agent': 'AWeber-Python-code-sample/1.0',
            'Authorization': f'Bearer {access_token}'
        }
        response = requests.get(lists_url, headers=headers)
        response.raise_for_status()
        campaign_details = response.json()


        print(f"Details for campaign {account_id} fetched successfully!")
        lists=[]
        for entry in campaign_details['entries']:
            lists+=[entry['id']]

        return lists
    except requests.exceptions.RequestException as e:
        print(f"Error fetching lists for account {account_id}:", e)
        return {}

def get_campaign_details(account_id, list_id, campaign_id, campaign_type, access_token):
    try:
        
        campaign_details_url = f'https://api.aweber.com/1.0/accounts/{account_id}/lists/{list_id}/campaigns/{campaign_type}{campaign_id}'
        headers = {
            'Accept': 'application/json',
            'User-Agent': 'AWeber-Python-code-sample/1.0',
            'Authorization': f'Bearer {access_token}'
        }
        response = requests.get(campaign_details_url, headers=headers)
        response.raise_for_status()
        campaign_details = response.json()
        campaign_details['sent_at_cet'] = convert_to_cet(campaign_details['sent_at'])
        campaign_details['list_id'] = list_id
        print(f"Details for campaign {campaign_id} fetched successfully!")
        time.sleep(sleep_time_for_one_campaign)
        return campaign_details
    except requests.exceptions.RequestException as e:
        print(f"Error fetching details for campaign {campaign_id}:", e)
        return {}



def fetch_all_campaigns_of_list_and_type(account_id, list_id, campaign_type, data_nature):
    aweber, access_token = get_aweber_session()
    

    campaigns_response = get_campaigns(list_id, account_id, campaign_type, limit=limit_per_request)
    campaigns = campaigns_response['entries']
    all_campaigns_of_list_and_type_details = []
    for campaign in campaigns:
        campaign_id = campaign['id']
        print(f"campaign is {campaign_id} and list is {list_id}")
        if data_nature=='campaigns_stats':
            campaign_details = get_campaign_details(account_id, list_id, campaign_id, campaign_type, access_token)
        elif data_nature=='campaigns_characteristics':
            campaign_details = get_campaign_characteristics(account_id, list_id, campaign_id, campaign_type, access_token)
        #print(type(campaign_details['sent_at_cet']))
        all_campaigns_of_list_and_type_details.append(campaign_details)
    return all_campaigns_of_list_and_type_details

def fetch_all_campaigns(account_id, campaign_type_set, data_nature):
    all_campaigns_details = []
    lists=get_all_lists_for_account(account_id)
    #print(entries)
    for list_id in lists:
        for campaign_type in campaign_type_set:
            all_campaigns_details = all_campaigns_details+fetch_all_campaigns_of_list_and_type(account_id, list_id, campaign_type, data_nature)
    return all_campaigns_details, lists

# %%
# Example usage:
account_id = 2007954  # Replace with actual account ID
list_id = 6405738  # Replace with actual list ID
campaign_type = 'b'  # Replace with actual campaign type (e.g., 'broadcast', 'followup', etc.)

all_campaigns_details_final, lists = fetch_all_campaigns(account_id, campaign_type_set=['b', 'f'], data_nature='campaigns_stats')

# Print or process all campaign details
#print(json.dumps(all_campaigns_details_final, indent=2))
# Out:
# Details for campaign 2007954 fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6405738/campaigns?ws.op=find&campaign_type=b&ws.start=0&ws.size=1
# Campaigns fetched successfully!
# campaign is 58034482 and list is 6405738
# Details for campaign 58034482 fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6405738/campaigns?ws.op=find&campaign_type=f&ws.start=0&ws.size=1
# Campaigns fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6405739/campaigns?ws.op=find&campaign_type=b&ws.start=0&ws.size=1
# Campaigns fetched successfully!
# campaign is 58034621 and list is 6405739
# Details for campaign 58034621 fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6405739/campaigns?ws.op=find&campaign_type=f&ws.start=0&ws.size=1
# Campaigns fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6405742/campaigns?ws.op=find&campaign_type=b&ws.start=0&ws.size=1
# Campaigns fetched successfully!
# campaign is 58034846 and list is 6405742
# Details for campaign 58034846 fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6405742/campaigns?ws.op=find&campaign_type=f&ws.start=0&ws.size=1
# Campaigns fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6405745/campaigns?ws.op=find&campaign_type=b&ws.start=0&ws.size=1
# Campaigns fetched successfully!
# campaign is 58034178 and list is 6405745
# Details for campaign 58034178 fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6405745/campaigns?ws.op=find&campaign_type=f&ws.start=0&ws.size=1
# Campaigns fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6405748/campaigns?ws.op=find&campaign_type=b&ws.start=0&ws.size=1
# Campaigns fetched successfully!
# campaign is 58034711 and list is 6405748
# Details for campaign 58034711 fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6405748/campaigns?ws.op=find&campaign_type=f&ws.start=0&ws.size=1
# Campaigns fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6405762/campaigns?ws.op=find&campaign_type=b&ws.start=0&ws.size=1
# Campaigns fetched successfully!
# campaign is 58034533 and list is 6405762
# Details for campaign 58034533 fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6405762/campaigns?ws.op=find&campaign_type=f&ws.start=0&ws.size=1
# Campaigns fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6405764/campaigns?ws.op=find&campaign_type=b&ws.start=0&ws.size=1
# Campaigns fetched successfully!
# campaign is 58034573 and list is 6405764
# Details for campaign 58034573 fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6405764/campaigns?ws.op=find&campaign_type=f&ws.start=0&ws.size=1
# Campaigns fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6405767/campaigns?ws.op=find&campaign_type=b&ws.start=0&ws.size=1
# Campaigns fetched successfully!
# campaign is 58034994 and list is 6405767
# Details for campaign 58034994 fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6405767/campaigns?ws.op=find&campaign_type=f&ws.start=0&ws.size=1
# Campaigns fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6405771/campaigns?ws.op=find&campaign_type=b&ws.start=0&ws.size=1
# Campaigns fetched successfully!
# campaign is 58034933 and list is 6405771
# Details for campaign 58034933 fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6405771/campaigns?ws.op=find&campaign_type=f&ws.start=0&ws.size=1
# Campaigns fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6456354/campaigns?ws.op=find&campaign_type=b&ws.start=0&ws.size=1
# Campaigns fetched successfully!
# campaign is 58033988 and list is 6456354
# Details for campaign 58033988 fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6456354/campaigns?ws.op=find&campaign_type=f&ws.start=0&ws.size=1
# Campaigns fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6498565/campaigns?ws.op=find&campaign_type=b&ws.start=0&ws.size=1
# Campaigns fetched successfully!
# campaign is 56647645 and list is 6498565
# Details for campaign 56647645 fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6498565/campaigns?ws.op=find&campaign_type=f&ws.start=0&ws.size=1
# Campaigns fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6679170/campaigns?ws.op=find&campaign_type=b&ws.start=0&ws.size=1
# Campaigns fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6679170/campaigns?ws.op=find&campaign_type=f&ws.start=0&ws.size=1
# Campaigns fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6784256/campaigns?ws.op=find&campaign_type=b&ws.start=0&ws.size=1
# Campaigns fetched successfully!
# campaign is 58013011 and list is 6784256
# Details for campaign 58013011 fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6784256/campaigns?ws.op=find&campaign_type=f&ws.start=0&ws.size=1
# Campaigns fetched successfully!

# %% [markdown]
# ## Uploading Data to postgres

# %%
# with open(sql_creds, 'r') as file:
#     sql_credentials = json.load(file)

# sql_credentials['string']

# %%
from sqlalchemy import create_engine
#import pandas as pd

sql_creds = creds_path+'postgres_credentials.json'

# Load the credentials
with open(sql_creds, 'r') as file:
    sql_credentials = json.load(file)

def load_data_to_db(json_vector=all_campaigns_details_final, schema='danila', table='stg_aweber__campaign_data'):
    engine = create_engine(sql_credentials['string'])
    df=pd.json_normalize(json_vector)
    # Define CET timezone
    cet = pytz.timezone('Europe/Paris')
        
    # Add current timestamp in CET timezone
    df['updated_at_cet'] = datetime.now(cet)

    # Load data into the specified schema in the database
    df.to_sql(table, engine, if_exists='replace', index=False, schema='danila')

if __name__ == "__main__":
    load_data_to_db()

# %% [markdown]
# # Getting campaign country and brand

# %%
# Function to extract the specific part from the body_text
def extract_cosmic_slot(body_text):
    print(body_text)
    pattern = r'-email-([^-]*)-([^-]*)-([^-]*)-([^-]*)-([a-zA-Z_]*)'
    match = re.search(pattern, body_text)
    #string = '-email-nl-xxxxxxxxxxxxxxxx-justbit-'
    if match:
        return match.group(1), match.group(3), (match.group(5)=='trickyspins_email_welcome')
    return None, None, None

def get_campaign_characteristics(account_id, list_id, campaign_id, campaign_type, access_token):
    try:
        aweber, access_token = get_aweber_session()
        campaign_details_url = f'https://api.aweber.com/1.0/accounts/{account_id}/lists/{list_id}/broadcasts/{campaign_id}'
        
        headers = {
            'Accept': 'application/json',
            'User-Agent': 'AWeber-Python-code-sample/1.0',
            'Authorization': f'Bearer {access_token}'
        }
        response = requests.get(campaign_details_url, headers=headers)
        response.raise_for_status()
        json_data = response.json()
        country_code, brand_name, is_welcome_campaign=extract_cosmic_slot(json_data['body_text'])
        extracted_data = {
            'brand_name': brand_name,
            'country_code': country_code,
            'is_welcome_campaign': is_welcome_campaign,
            'sent_at': json_data['sent_at'],
            'sent_at_cet': convert_to_cet(json_data['sent_at']), # Convert to CET timezone
            'broadcast_id': json_data['broadcast_id'],
            'campaign_type': campaign_type,
            'campaign_id': campaign_id,
            'account_id': account_id,
            'list_id': list_id,
            'subject': json_data['subject'],
            'num_complaints': json_data['stats']['num_complaints'],
            'num_emailed': json_data['stats']['num_emailed'],
            'num_undeliv': json_data['stats']['num_undeliv'],
            'unique_clicks': json_data['stats']['unique_clicks'],
            'unique_opens': json_data['stats']['unique_opens']
        }
        # campaign_details['sent_at_cet'] = convert_to_cet(campaign_details['sent_at'])
        # campaign_details['list_id'] = list_id
        print(f"Details for campaign {campaign_id} fetched successfully!")
        time.sleep(sleep_time_for_one_campaign)
        return extracted_data
    except requests.exceptions.RequestException as e:
        print(f"Error fetching details for campaign {campaign_id}:", e)
        return {}

campaign_id= 57913875 # 57961057
account_id = 2007954  # Replace with actual account ID
list_id = 6405738  # Replace with actual list ID
#aweber, access_token = get_aweber_session()
campaign_characteristics, lists = fetch_all_campaigns(account_id, campaign_type_set='b', data_nature='campaigns_characteristics')


string="email-202301010000-undefined-undefined-0-email-de-xxxxxxxxxxxxxxxx-cobra-undefined-trickyspins_email"
#extract_cosmic_slot(string)
#print(campaign_characteristics)
# Out:
# Details for campaign 2007954 fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6405738/campaigns?ws.op=find&campaign_type=b&ws.start=0&ws.size=1
# Campaigns fetched successfully!
# campaign is 58034482 and list is 6405738
# SpinAway with 10 free spins per day in Big Bass Bonanza.
#
# https://media.spinawaypartners.com/redirect.aspx?pid=3353&lpid=6&bid=1476&subid=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-spinaway-undefined-trickyspins_email_newbase
#
#             Collect 100 Free Spins Right After Your First Deposit!
#
# https://media.spinawaypartners.com/redirect.aspx?pid=3353&lpid=6&bid=1476&subid=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-spinaway-undefined-trickyspins_email_newbase
#
#
# Yes, you read that right! Make your first deposit with us and unlock a treasure chest of 100 free spins. But that's not all - we're spreading the joy to ensure your adventure keeps getting better day by day.
#
#
#             You received this message because you have subscribed to TrickySpins.
#
# https://trickyspins.com/
#
# Learn more about the new offers, playing strategies and best practices!
#
# https://trickyspins.com/
#
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 58034482 fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6405739/campaigns?ws.op=find&campaign_type=b&ws.start=0&ws.size=1
# Campaigns fetched successfully!
# campaign is 58034621 and list is 6405739
# Unleash Fiery Fortunes with Coin Volcano
#
#                         Coin Volcano highest RTP
#
# https://m.media13aff.com/Redirect.aspx?mid=112&sid=43014&affid=506&cid=email-202301010000-undefined-undefined-0-email-au-xxxxxxxxxxxxxxxx-spinbro-undefined-trickyspins_email_newbase
#
#             Get ready for an explosive adventure with Coin Volcano, the latest 3x3 reel game by Booongo!
#
# Featuring the thrilling hold & win bonus game and the enhanced ultra bonus game, this high RTP slot
#
# https://m.media13aff.com/Redirect.aspx?mid=112&sid=43014&affid=506&cid=email-202301010000-undefined-undefined-0-email-au-xxxxxxxxxxxxxxxx-spinbro-undefined-trickyspins_email_newbase
#  promises endless excitement.
#
# Watch as reels erupt with coins, volcano multipliers, and four fiery jackpots. trigger the bonus game with three symbols on the middle reel, and enjoy respins that reset with every new symbol. Look out for the scorching ball, which collects all coin and jackpot values in view.
#
#
#             You received this message because you have subscribed to TrickySpins.
# Learn more about the new offers, playing strategies and best practices!
#
# https://trickyspins.com/au/home
#
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 58034621 fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6405742/campaigns?ws.op=find&campaign_type=b&ws.start=0&ws.size=1
# Campaigns fetched successfully!
# campaign is 58034846 and list is 6405742
# 100 mBTC
#
#                         Krypto-Willkommensangebot Bis zu 100 mBTC + 100 FS +  1 Bonuskrabbe
#
# https://st.lp247p.com/C.ashx?btag=a_10435b_510c_&affid=786&siteid=10435&adid=510&c=email-202301010000-undefined-undefined-0-email-au-xxxxxxxxxxxxxxxx-sportaza-undefined-trickyspins_email_newbase
#
#             Willkommen bei Sportaza Casino, wo Ihre Leidenschaft für Spiele und Kryptowährungen auf das perfekte Angebot trifft!
#
#  Registrieren Sie sich jetzt als Neukunde und sichern Sie sich unser exklusives Krypto-Willkommenspaket. Nehmen Sie Ihre erste Echtgeld-Einzahlung mit einer unserer akzeptierten Kryptowährungen vor und profitieren Sie von bis zu 100 mBTC und 100 Freispielen.
#
# https://st.lp247p.com/C.ashx?btag=a_10435b_510c_&affid=786&siteid=10435&adid=510&c=email-202301010000-undefined-undefined-0-email-au-xxxxxxxxxxxxxxxx-sportaza-undefined-trickyspins_email_newbase
#  Zusätzlich gibt es eine Bonuskrabbe oben drauf! Akzeptierte Kryptowährungen:
# Bitcoin (BTC), Bitcoin Cash (BCH), Tether (USDT), Litecoin (LTC), Ethereum, (ETH), Ripple (XRP), USD Coin (USDC), DAI.
#
# Nutzen Sie die Kraft der Kryptowährungen für ein sichereres und schnelleres Spielerlebnis. Verpassen Sie nicht die Chance, Ihr Spiel auf das nächste Level zu heben!
#
#
# Sie haben diese Nachricht erhalten, weil Sie sich bei TrickySpins
# angemeldet haben.
#
#             Erfahren Sie mehr über die neuen Angebote, Spielstrategien und Best Practices!
# DISCLAIMER: Wir sind kein Glücksspielanbieter. Unser Service besteht darin, die besten verfügbaren Angebote für unsere Abonnenten zu entdecken, zu vergleichen und auszuhandeln. Willkommensangebote gelten nur für neue Spieler. Es gelten die allgemeinen Geschäftsbedingungen. 18+
# Wir unterstützen verantwortungsbewusstes Spielen. Wir sind hier, um Ihnen zu helfen, die Kontrolle zu behalten und sicherzustellen, dass Glücksspiel ein angenehmes Erlebnis bleibt.
# Details for campaign 58034846 fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6405745/campaigns?ws.op=find&campaign_type=b&ws.start=0&ws.size=1
# Campaigns fetched successfully!
# campaign is 58034178 and list is 6405745
# 100% bonus asti 120€ + 120  ilmaiskierrosta
#
# https://media.affiliatestonybet.com/redirect.aspx?pid=163743&bid=1991&lpid=1009=email-202301010000-undefined-undefined-0-email-fi-xxxxxxxxxxxxxxxx-posido-undefined-trickyspins_email_newbase
#
#             Hei kaikki jännityksen etsijät ja viihteen ystävät!
#
# Tonybet tarjoaa kesäkuumennuksen uusille pelaajille uskomattoman tervetuliaisbonuksen, joka sytyttää pelimaailmasi!
# Liityt mukaan upeaan yhteisöömme, saat mahtavan 100% bonuksen ensimmäisestä talletuksestasi, jopa yhteensä 120 € asti!
#
# https://media.affiliatestonybet.com/redirect.aspx?pid=163743&bid=1991&lpid=1009=email-202301010000-undefined-undefined-0-email-fi-xxxxxxxxxxxxxxxx-posido-undefined-trickyspins_email_newbase
#
#
# Kyllä, luit oikein - me tuplaamme ensimmäisen talletuksesi, jotta peliaikasi ja mahdollisuutesi osua mega-jackpotteihin kasvavat! Mutta hauskuus ei lopu tähän, sillä heitämme vielä päälle 120 ilmaiskierrosta makean diilin kruunaamiseksi!  Pyöräytä keloja suosituimmissa sloteissamme ja koe voiton huuma käyttämättä senttiäkään talletuksestasi.
#
#
# Sait tämän viestin, koska olet tilannut TrickySpins.
#
# Lue lisää uusista tarjouksista, pelistrategioista ja parhaista käytännöistä!
#
# DISCLAIMER: Emme ole uhkapelioperaattori. Palvelumme on löytää, vertailla ja neuvotella parhaat saatavilla olevat tarjoukset tilaajillemme. Tervetulotarjoukset on tarkoitettu vain uusille pelaajille. Säännöt ja ehdot ovat voimassa. 18+
# Details for campaign 58034178 fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6405748/campaigns?ws.op=find&campaign_type=b&ws.start=0&ws.size=1
# Campaigns fetched successfully!
# campaign is 58034711 and list is 6405748
# 40% Bonus bis zu 100€!
#
#                         Wochenend Reload Bonus Samstag, Sonntag 40% bis zu €100
#
# https://trackerfortuneio.com/me7a4ef39?click_id=email-202401010000-undefined-undefined-0-email-de-xxxxxxxxxxxxxxxx-wildfortune-undefined-trickyspins_email_newbase
#
#             Machen Sie sich bereit für ein spektakuläres Wochenende mit unserem exklusiven Weekend Reload Bonus! Jeden Samstag und Sonntag erhalten Sie einen satten
# 40% Bonus bis zu 100€!
#
# https://trackerfortuneio.com/me7a4ef39?click_id=email-202401010000-undefined-undefined-0-email-de-xxxxxxxxxxxxxxxx-wildfortune-undefined-trickyspins_email_newbase
#
# Hier erfahren Sie, wie Sie Ihren Bonus anfordern können:
#
# 1️⃣ Verwenden Sie den Bonuscode: WEEKEND
#
# 2️⃣ Machen Sie eine Mindesteinzahlung von €20
#
# Verpassen Sie nicht diese Chance, Ihr Spiel zu steigern und groß zu gewinnen! Egal, ob Sie an den Walzen drehen oder Karten spielen, machen Sie Ihr Wochenende zum Erlebnis.
#
#
# Sie haben diese Nachricht erhalten, weil Sie sich bei TrickySpins
# angemeldet haben.
#
#             Erfahren Sie mehr über die neuen Angebote, Spielstrategien und Best Practices!
# DISCLAIMER: Wir sind kein Glücksspielanbieter. Unser Service besteht darin, die besten verfügbaren Angebote für unsere Abonnenten zu entdecken, zu vergleichen und auszuhandeln. Willkommensangebote gelten nur für neue Spieler. Es gelten die allgemeinen Geschäftsbedingungen. 18+
# Wir unterstützen verantwortungsbewusstes Spielen. Wir sind hier, um Ihnen zu helfen, die Kontrolle zu behalten und sicherzustellen, dass Glücksspiel ein angenehmes Erlebnis bleibt.
# Details for campaign 58034711 fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6405762/campaigns?ws.op=find&campaign_type=b&ws.start=0&ws.size=1
# Campaigns fetched successfully!
# campaign is 58034533 and list is 6405762
# 75% up to €200 + 50 Free Spins
#
# https://lalatrackers.com/daf2b59b9?click_id=email-202401010000-undefined-undefined-0-email-nl-xxxxxxxxxxxxxxxx-lalabet-undefined-trickyspins_email_newbase
#
#             It's time to embark on an unforgettable gaming journey!
#
# As a warm welcome, we are offering you an incredible bonus:
#  receive a 75% match bonus on your first deposit, up to €200.
#
# https://lalatrackers.com/daf2b59b9?click_id=email-202401010000-undefined-undefined-0-email-nl-xxxxxxxxxxxxxxxx-lalabet-undefined-trickyspins_email_newbase
#
# With your increased balance, you can explore our extensive selection of games and stand a chance to win big.
# Hurry, your ultimate casino adventure awaits!
#
#             You received this message because you have subscribed to TrickySpins.
# Learn more about the new offers, playing strategies and best practices!
#
#
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 58034533 fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6405764/campaigns?ws.op=find&campaign_type=b&ws.start=0&ws.size=1
# Campaigns fetched successfully!
# campaign is 58034573 and list is 6405764
# Join Now!
#
#                         €1000 plus 150 free spins!
#
# https://online.dachbet.com/promoRedirect?key=ej0xMzUyNDUyMCZsPTAmcD01NDYx&var1=email-202401010000-undefined-undefined-0-email-nz-xxxxxxxxxxxxxxxx-dachbet-undefined-trickyspins_email_newbase
#
#             Dachbet Casino has an incredible offer of €1000 plus 150 free spins!
#
# https://online.dachbet.com/promoRedirect?key=ej0xMzUyNDUyMCZsPTAmcD01NDYx&var1=email-202401010000-undefined-undefined-0-email-nz-xxxxxxxxxxxxxxxx-dachbet-undefined-trickyspins_email_newbase
#
#
# With these amazing bonuses, you have the opportunity to choose one or even grab both for maximum reward. Don't miss out on these incredible bonuses - they won't last long!
#
#             You received this message because you have subscribed to TrickySpins.
# Learn more about the new offers, playing strategies and best practices!
#
#
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 58034573 fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6405767/campaigns?ws.op=find&campaign_type=b&ws.start=0&ws.size=1
# Campaigns fetched successfully!
# campaign is 58034994 and list is 6405767
# Bare for VIP
#
#                         VIP PROGRAM
#
# https://media.hellpartners.com/redirect.aspx?pid=21018&bid=1466&lpid=307&dynamic=email-202301010000-undefined-undefined-0-email-no-xxxxxxxxxxxxxxxx-hellspin-undefined-trickyspins_email_newbase
#
#
# Oppdag ukens topp 3 velkomstbonuser!
#
#                         Velkomstbonus 100% på opptil 5000 kr + 200 GS + 1 Bonus Crab
#
# https://lunubetplay.com/ja6286d51?subid=email-202401010000-undefined-undefined-0-email-no-xxxxxxxxxxxxxxxx-lunubet-undefined-trickyspins_email_newbase
#
#                         Velkomstbonus 100% på opptil 20.000 kr + 200 GS
#
# https://levelupromo.com/aad388087?click_id=email-202401010000-undefined-undefined-0-email-no-xxxxxxxxxxxxxxxx-levelup-undefined-trickyspins_email_newbase
#
#                         Velkomstbonus 100% på opptil 5000 kr + 200 GS + 1 Bonus Crab
#
# https://media.nomini.com/redirect.aspx?pid=2029414&lpid=4132&bid=4994&var2=email-202301010000-undefined-undefined-0-email-no-xxxxxxxxxxxxxxxx-nomini-undefined-trickyspins_email_newbase
#
#             Er du klar for å begi deg ut på et spennende eventyr med ukens beste bonuser? Hos TrickySpins har vi håndplukket de 3 beste velkomstbonusene bare for deg, slik at spillopplevelsen din starter med et smell!
#
#
#
#             Du mottok denne meldingen fordi du har abonnert på  TrickySpins.
#
# https://trickyspins.com/no/home
#
# Lær mer om de nye tilbudene, spillestrategier og beste praksiser!
#
# https://trickyspins.com/no/home
#
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 21+
# Details for campaign 58034994 fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6405771/campaigns?ws.op=find&campaign_type=b&ws.start=0&ws.size=1
# Campaigns fetched successfully!
# campaign is 58034933 and list is 6405771
# 400€ Bonusgeld
#
#                         Einzahlungsbonus 400 eur + 20 Freispiele
#
# https://partnersredirect.com/af397ab5f?clickid=email-202301010000-undefined-undefined-0-email-ch-xxxxxxxxxxxxxxxx-spinsamurai-undefined-trickyspins_email_newbase
#
#             Verpasst nicht diese fantastische Gelegenheit, um eure Gewinne zu maximieren!
# Erhaltet mehr als 400€ Bonusgeld
#
# https://partnersredirect.com/af397ab5f?clickid=email-202301010000-undefined-undefined-0-email-ch-xxxxxxxxxxxxxxxx-spinsamurai-undefined-trickyspins_email_newbase
#  und steigert eure Gewinnchancen!
# Als ob das noch nicht genug wäre, gibt es zusätzlich 20 Freispiele für noch mehr Spielspaß!
#
#
# Sie haben diese Nachricht erhalten, weil Sie sich bei TrickySpins
# angemeldet haben.
#
#             Erfahren Sie mehr über die neuen Angebote, Spielstrategien und Best Practices!
# DISCLAIMER: Wir sind kein Glücksspielanbieter. Unser Service besteht darin, die besten verfügbaren Angebote für unsere Abonnenten zu entdecken, zu vergleichen und auszuhandeln. Willkommensangebote gelten nur für neue Spieler. Es gelten die allgemeinen Geschäftsbedingungen. 18+
# Wir unterstützen verantwortungsbewusstes Spielen. Wir sind hier, um Ihnen zu helfen, die Kontrolle zu behalten und sicherzustellen, dass Glücksspiel ein angenehmes Erlebnis bleibt.
# Details for campaign 58034933 fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6456354/campaigns?ws.op=find&campaign_type=b&ws.start=0&ws.size=1
# Campaigns fetched successfully!
# campaign is 58033988 and list is 6456354
# R$20.000.000
#
#                         R$2.000.000,00
#
# https://record.ibetaffiliates.com/_EEcsKdwcyyrITHy77psZsWNd7ZgqdRLk/7/?pg=4?payload=email-202301010000-undefined-undefined-0-email-no-xxxxxxxxxxxxxxxx-ibet-undefined-trickyspins_email_newbase
#
#             Prepare-se para uma aventura encantadora enquanto revelamos a Surpresa Misteriosa da Wazdan
#
# Do dia 14 de maio até 29 de setembro, você terá grandes oportunidades para desbloquear sua parte, ou partes, do fascinante prêmio de R$20.000.000
#
# https://record.ibetaffiliates.com/_EEcsKdwcyyrITHy77psZsWNd7ZgqdRLk/7/?pg=4?payload=email-202301010000-undefined-undefined-0-email-no-xxxxxxxxxxxxxxxx-ibet-undefined-trickyspins_email_newbase
#
#
# Jogue qualquer jogo da Wazdan e escolha entre 9 recompensas irresistíveis da Caixa Misteriosa, cada uma escondendo seus próprios tesouros, revelados somente após você fazer sua seleção.
#
# Os prêmios tentadoras de R$200, R$100, R$50 e R$25 caem misteriosamente aproximadamente a cada 2,5 minutos, em média
#
# Não perca essa chance de explorar os títulos fascinantes da série Coins, conhecidos por seu apelo mágico e extraordinárias oportunidades de vitória.
#
# Envolva-se nesse mistério e deixe a Lady Fortune guiar seu caminho no ibet!
#
#
#
#             Você recebeu esta mensagem porque se inscreveu no TrickySpins.
# Saiba mais sobre as novas ofertas, estratégias de jogo e práticas recomendadas!
# DISCLAIMER: Não somos uma operadora de jogos de azar. Nosso serviço consiste em descobrir, comparar e negociar as melhores ofertas disponíveis para nossos assinantes. As ofertas de boas-vindas são apenas para novos jogadores. Aplicam-se termos e condições. 18+ Apoiamos o jogo responsável. Estamos aqui para ajudá-lo a manter o controle e garantir que o jogo continue sendo uma experiência agradável.
# Details for campaign 58033988 fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6498565/campaigns?ws.op=find&campaign_type=b&ws.start=0&ws.size=1
# Campaigns fetched successfully!
# campaign is 56647645 and list is 6498565
# Logo
#
# http://www.aweber.com
#
#
#
#                         Loyalty prorgamm 7% Cosmic Coins for each deposit
#
# https://m.media13aff.com/Redirect.aspx?mid=53&sid=4305&affid=506&cid=email-202301010000-undefined-undefined-0-email-au-xxxxxxxxxxxxxxxx-cosmicslot-undefined-trickyspins_email
#
#             CosmicSlot is a preferred destination for players who want to feel the excitement from the best slot games.
# Don’t miss a unique opportunity of getting an adorable bonus, which we have prepared for you today.
# Grab it and have fun playing!
#
#                                 I'm in!
#
# https://m.media13aff.com/Redirect.aspx?mid=53&sid=4305&affid=506&cid=email-202301010000-undefined-undefined-0-email-au-xxxxxxxxxxxxxxxx-cosmicslot-undefined-trickyspins_email
#
#                         Coins can be redeemed for bonuses or free spins in the bonus store.
#
# https://m.media13aff.com/Redirect.aspx?mid=53&sid=4305&affid=506&cid=email-202301010000-undefined-undefined-0-email-au-xxxxxxxxxxxxxxxx-cosmicslot-undefined-trickyspins_email
#
#             You received this message because you have subscribed to TrickySpins.
#
# https://trickyspins.com/au/home
#
# Learn more about the new offers, playing strategies and best practices!
#
# https://trickyspins.com/au/home
#
#
#
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 56647645 fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6679170/campaigns?ws.op=find&campaign_type=b&ws.start=0&ws.size=1
# Campaigns fetched successfully!
# Fetching campaigns with URL: https://api.aweber.com/1.0/accounts/2007954/lists/6784256/campaigns?ws.op=find&campaign_type=b&ws.start=0&ws.size=1
# Campaigns fetched successfully!
# campaign is 58013011 and list is 6784256
# Unleash Fiery Fortunes with Coin Volcano
#
#                         Coin Volcano highest RTP
#
# https://m.media13aff.com/Redirect.aspx?mid=100&sid=4316&affid=506&cid=email-202301010000-undefined-undefined-0-email-ca-{{subscriber.id}}-spinbro-undefined-trickyspins_email_newbase
#
#             Get ready for an explosive adventure with Coin Volcano, the latest 3x3 reel game by Booongo!
#
# Featuring the thrilling hold & win bonus game and the enhanced ultra bonus game, this high RTP slot
#
# https://m.media13aff.com/Redirect.aspx?mid=100&sid=4316&affid=506&cid=email-202301010000-undefined-undefined-0-email-ca-xxxxxxxxxxxxxxxx-spinbro-undefined-trickyspins_email_newbase
#  promises endless excitement.
#
# Watch as reels erupt with coins, volcano multipliers, and four fiery jackpots. trigger the bonus game with three symbols on the middle reel, and enjoy respins that reset with every new symbol. Look out for the scorching ball, which collects all coin and jackpot values in view.
#
#
#             You received this message because you have subscribed to TrickySpins.
# Learn more about the new offers, playing strategies and best practices!
#
# https://trickyspins.com/au/home
#
# DISCLAIMER: We are not a gambling operator. Our service is to discover, compare, and negotiate the best available offers for our subscribers. Welcome offers are for new players only. Terms and conditions apply. 18+
# We support responsible gaming. We are here to assist you in maintaining control and ensuring that gambling remains an enjoyable experience.
# Details for campaign 58013011 fetched successfully!
# email-202301010000-undefined-undefined-0-email-de-xxxxxxxxxxxxxxxx-cobra-undefined-trickyspins_email
# ('de', 'cobra', False)

# %%
# string="202301010000-undefined-undefined-0-email-de-xxxxxxxxxxxxxxxx-cobra-undefined-trickyspins_email_welcome"
# extract_cosmic_slot(string)

# %%
#if __name__ == "__main__":
load_data_to_db(json_vector=campaign_characteristics, schema='danila', table='stg_aweber__campaign_characteristics')
